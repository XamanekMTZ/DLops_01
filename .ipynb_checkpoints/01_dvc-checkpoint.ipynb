# %%
# %pip install scikit-learn

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 10000
)

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# Requirement already satisfied: scikit-learn in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.
# /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(
# (60000, 10000, 60000, 10000)

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
import random

fig = plt.figure( dpi = 100 )
for ix in range ( 25 ):
    ax = plt.subplot( 5, 5, ix + 1 )
    i = random.randint( 0, len(X_train) - 1 )
    img, label = X_train[i], y_train[i]
    ax.imshow( img.reshape( 28, 28 ), cmap = 'gray' )
    ax.set_title( label )
    ax.axis( 'off' )
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: matplotlib in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

X_train_3 = X_train[ y_train == '3' ][:100]
X_train_no_3 = X_train[ y_train != '3' ][:100]

len(X_train_3), len(X_train_no_3)
# Out:
# (100, 100)

# %%
def plot_samples(X):
    fig = plt.figure(dpi=100)
    for ix in range(25):
        ax = plt.subplot( 5, 5, ix + 1 )
        i = random.randint( 0, len(X)-1 )
        img = X[i]
        ax.imshow( img.reshape( 28, 28), cmap = 'gray' )
        ax.axis( 'off' )
    plt.tight_layout()
    plt.show()

# %%
plot_samples(X_train_3)

# %%
plot_samples(X_train_no_3)

# %%
# %pip install scikit-image
import os
from pathlib import Path
from skimage.io import imsave
import shutil

path = Path('dataset')

def generate_dataset(X_train_3, X_train_no_3, test_size):
    shutil.rmtree(path)
    #os.makedirs(path, exist_ok=True)
    isExist = os.path.exists(path)
    #print(isExist)
    if not isExist:
        os.makedirs(path)

    splits = ['train', 'test']
    for split in splits:
        os.makedirs( path / split, exist_ok = True )
        os.makedirs( path / split / '3', exist_ok = True )
        os.makedirs( path / split / 'no3', exist_ok = True )
        if split == 'train':
            X1, X2 = X_train_3[:-test_size], X_train_no_3[:-test_size]
        else:
            X1, X2 = X_train_3[-test_size:], X_train_no_3[-test_size:]
        for x1, x2 in zip(X1, X2):
            #imsave( path / split / '3' / f'{random.randint( 0, 99999):05d}.png', x1.reshape( 28, 28 ).astype( 'uint8' ) )
            #imsave( path / split / 'no_3' / f'{random.randint(0, 99999):05d}.png', x2.reshape( 28, 28 ).astype( 'uint8' ) )
            imsave(path / split / '3' / f'{random.randint(0, 99999):05d}.png', x1.reshape(28,28).astype('uint8'))
            imsave(path / split / 'no3' / f'{random.randint(0, 99999):05d}.png', x2.reshape(28,28).astype('uint8'))
# Out:
# Requirement already satisfied: scikit-image in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.21.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (1.25.2)
# Requirement already satisfied: scipy>=1.8 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (1.11.1)
# Requirement already satisfied: networkx>=2.8 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (10.0.0)
# Requirement already satisfied: imageio>=2.27 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=21 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in /home/xamanek/.virtualenvs/DLops01/lib/python3.10/site-packages (from scikit-image) (0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
generate_dataset( X_train_3, X_train_no_3, 20 )

# %%
from glob import glob

def get_paths():
    train_3 = glob( str( path / 'train' / '3' / '*.png' ) )
    train_no3 = glob( str( path / 'train' / 'no3' / '*.png' ) )
    test_3 = glob( str( path / 'test' / '3' / '*.png' ) )
    test_no3 = glob( str( path / 'test' / 'no3' / '*.png' ) )
    return train_3, train_no3, test_3, test_no3

train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (80, 80, 20, 20)

# %%
from skimage.io import imread

def plot_images(paths):
    #fig = plt.figure(dpi=100)
    for ix in range(25):
        ax = plt.subplot( 5, 5, ix + 1 )
        i = random.randint( 0, len(paths) - 1 )
        img = imread( paths[i] )
        ax.imshow( img, cmap = 'gray' )
        ax.axis( 'off' )

    plt.tight_layout()
    plt.show()

# %%
plot_images(train_3)

# %%
plot_images(train_no3)

# %%
X_train_3 = X_train[y_train == '3'][:200]
X_train_no_3 = X_train[y_train != '3'][:200]

len(X_train_3), len(X_train_no_3)
# Out:
# (200, 200)

# %%
generate_dataset(X_train_3, X_train_no_3, 40)

# %%
train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (160, 160, 40, 40)

# %% [markdown]
# Nueva version 2 con 400 archivos

# %%
X_train_3 = X_train[y_train == '3'][:400]
X_train_no_3 = X_train[y_train != '3'][:400]

len(X_train_3), len(X_train_no_3)
# Out:
# (400, 400)

# %%
generate_dataset(X_train_3, X_train_no_3, 80)

# %%
train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (320, 320, 80, 80)

# %% [markdown]
# Revisar la version 1 con 200 registros y split de 160 / 40

# %%
train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (160, 160, 40, 40)

# %% [markdown]
# Volver a la version V2 con 400 registros y split de 320 / 80

# %%
train_3, train_no3, test_3, test_no3 = get_paths()

len(train_3), len(train_no3), len(test_3), len(test_no3)
# Out:
# (320, 320, 80, 80)
